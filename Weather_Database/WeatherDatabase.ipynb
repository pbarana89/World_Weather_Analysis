# %%
#Import the Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import time 
from datetime import datetime
from config import weather_api_key
import requests
import json
from scipy.stats import linregress

# %%
# Call the api
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 770

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of Set 1 | raga
# Processing Record 3 of Set 1 | kirakira
# Processing Record 4 of Set 1 | mataura
# Processing Record 5 of Set 1 | nizhniy tsasuchey
# Processing Record 6 of Set 1 | yongan
# Processing Record 7 of Set 1 | sao filipe
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | east london
# Processing Record 10 of Set 1 | orotukan
# Processing Record 11 of Set 1 | kapaa
# Processing Record 12 of Set 1 | port alfred
# Processing Record 13 of Set 1 | verkhoyansk
# Processing Record 14 of Set 1 | ribeira grande
# Processing Record 15 of Set 1 | ostrovnoy
# Processing Record 16 of Set 1 | whitehorse
# Processing Record 17 of Set 1 | korcula
# Processing Record 18 of Set 1 | zhanaozen
# Processing Record 19 of Set 1 | kutum
# Processing Record 20 of Set 1 | puerto suarez
# Processing Record 21 of Set 1 | port elizabeth
# Processing Record 22 of Set 1 | jiayuguan
# Processing Record 23 of Set 1 | butaritari
# Processing Record 24 of Set 1 | victoria
# Processing Record 25 of Set 1 | busselton
# Processing Record 26 of Set 1 | faanui
# Processing Record 27 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 28 of Set 1 | albany
# Processing Record 29 of Set 1 | nouadhibou
# Processing Record 30 of Set 1 | ancud
# Processing Record 31 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 32 of Set 1 | tiksi
# Processing Record 33 of Set 1 | rikitea
# Processing Record 34 of Set 1 | marienburg
# Processing Record 35 of Set 1 | ushuaia
# Processing Record 36 of Set 1 | puerto ayora
# Processing Record 37 of Set 1 | slave lake
# Processing Record 38 of Set 1 | jeremoabo
# Processing Record 39 of Set 1 | carutapera
# Processing Record 40 of Set 1 | chapais
# Processing Record 41 of Set 1 | havoysund
# Processing Record 42 of Set 1 | hermanus
# Processing Record 43 of Set 1 | esperance
# Processing Record 44 of Set 1 | cape town
# Processing Record 45 of Set 1 | narsaq
# Processing Record 46 of Set 1 | ust-nera
# Processing Record 47 of Set 1 | chiredzi
# Processing Record 48 of Set 1 | geraldton
# Processing Record 49 of Set 1 | khatanga
# Processing Record 50 of Set 1 | cremona
# Processing Record 1 of Set 2 | nanortalik
# Processing Record 2 of Set 2 | bengkulu
# Processing Record 3 of Set 2 | mackay
# Processing Record 4 of Set 2 | thompson
# Processing Record 5 of Set 2 | meadow lake
# Processing Record 6 of Set 2 | te anau
# Processing Record 7 of Set 2 | walvis bay
# Processing Record 8 of Set 2 | upernavik
# Processing Record 9 of Set 2 | constantine
# Processing Record 10 of Set 2 | mar del plata
# Processing Record 11 of Set 2 | isangel
# Processing Record 12 of Set 2 | inuvik
# Processing Record 13 of Set 2 | alofi
# Processing Record 14 of Set 2 | cidreira
# Processing Record 15 of Set 2 | antigua ocotepeque
# Processing Record 16 of Set 2 | ceres
# Processing Record 17 of Set 2 | jawor
# Processing Record 18 of Set 2 | maldonado
# Processing Record 19 of Set 2 | nanakuli
# Processing Record 20 of Set 2 | tahe
# Processing Record 21 of Set 2 | saskylakh
# Processing Record 22 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 23 of Set 2 | aykhal
# Processing Record 24 of Set 2 | soyo
# Processing Record 25 of Set 2 | luba
# Processing Record 26 of Set 2 | longyearbyen
# Processing Record 27 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 28 of Set 2 | aginskoye
# Processing Record 29 of Set 2 | castro
# Processing Record 30 of Set 2 | kattivakkam
# Processing Record 31 of Set 2 | bethel
# Processing Record 32 of Set 2 | ilheus
# Processing Record 33 of Set 2 | pisco
# Processing Record 34 of Set 2 | saint-pierre
# Processing Record 35 of Set 2 | bredasdorp
# Processing Record 36 of Set 2 | kavieng
# Processing Record 37 of Set 2 | kaitangata
# Processing Record 38 of Set 2 | oussouye
# Processing Record 39 of Set 2 | lebu
# Processing Record 40 of Set 2 | new norfolk
# Processing Record 41 of Set 2 | lorengau
# Processing Record 42 of Set 2 | hailar
# Processing Record 43 of Set 2 | tabou
# Processing Record 44 of Set 2 | qaanaaq
# Processing Record 45 of Set 2 | parvatsar
# Processing Record 46 of Set 2 | burica
# City not found. Skipping...
# Processing Record 47 of Set 2 | tigil
# Processing Record 48 of Set 2 | poggibonsi
# Processing Record 49 of Set 2 | ishigaki
# Processing Record 50 of Set 2 | teknaf
# Processing Record 1 of Set 3 | algiers
# Processing Record 2 of Set 3 | kieta
# Processing Record 3 of Set 3 | naze
# Processing Record 4 of Set 3 | zhezkazgan
# Processing Record 5 of Set 3 | ilulissat
# Processing Record 6 of Set 3 | meulaboh
# Processing Record 7 of Set 3 | hadejia
# Processing Record 8 of Set 3 | batemans bay
# Processing Record 9 of Set 3 | bluff
# Processing Record 10 of Set 3 | bandarbeyla
# Processing Record 11 of Set 3 | serebryansk
# Processing Record 12 of Set 3 | prince george
# Processing Record 13 of Set 3 | nerchinskiy zavod
# Processing Record 14 of Set 3 | moerai
# Processing Record 15 of Set 3 | kommunisticheskiy
# Processing Record 16 of Set 3 | uruzgan
# Processing Record 17 of Set 3 | lyndon
# Processing Record 18 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 3 | ust-tsilma
# Processing Record 20 of Set 3 | malwan
# City not found. Skipping...
# Processing Record 21 of Set 3 | jamestown
# Processing Record 22 of Set 3 | avarua
# Processing Record 23 of Set 3 | orshanka
# Processing Record 24 of Set 3 | eltham
# Processing Record 25 of Set 3 | zaria
# Processing Record 26 of Set 3 | challapata
# Processing Record 27 of Set 3 | poum
# Processing Record 28 of Set 3 | ponta do sol
# Processing Record 29 of Set 3 | taksimo
# Processing Record 30 of Set 3 | sinor
# Processing Record 31 of Set 3 | mahebourg
# Processing Record 32 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 33 of Set 3 | urdzhar
# City not found. Skipping...
# Processing Record 34 of Set 3 | tulle
# Processing Record 35 of Set 3 | vaini
# Processing Record 36 of Set 3 | mahon
# Processing Record 37 of Set 3 | sovetskiy
# Processing Record 38 of Set 3 | portland
# Processing Record 39 of Set 3 | nantucket
# Processing Record 40 of Set 3 | fairbanks
# Processing Record 41 of Set 3 | avera
# Processing Record 42 of Set 3 | beckley
# Processing Record 43 of Set 3 | rafsanjan
# Processing Record 44 of Set 3 | zhigansk
# Processing Record 45 of Set 3 | buin
# Processing Record 46 of Set 3 | viedma
# Processing Record 47 of Set 3 | sisimiut
# Processing Record 48 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 49 of Set 3 | barrow
# Processing Record 50 of Set 3 | ust-kuyga
# Processing Record 1 of Set 4 | karratha
# Processing Record 2 of Set 4 | tasbuget
# City not found. Skipping...
# Processing Record 3 of Set 4 | la ronge
# Processing Record 4 of Set 4 | praia
# Processing Record 5 of Set 4 | hobart
# Processing Record 6 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 7 of Set 4 | saint-augustin
# Processing Record 8 of Set 4 | russell
# Processing Record 9 of Set 4 | muros
# Processing Record 10 of Set 4 | taywarah
# Processing Record 11 of Set 4 | los llanos de aridane
# Processing Record 12 of Set 4 | mananjary
# Processing Record 13 of Set 4 | marawi
# Processing Record 14 of Set 4 | bambous virieux
# Processing Record 15 of Set 4 | kodiak
# Processing Record 16 of Set 4 | yellowknife
# Processing Record 17 of Set 4 | subaytilah
# City not found. Skipping...
# Processing Record 18 of Set 4 | tommot
# Processing Record 19 of Set 4 | mahajanga
# Processing Record 20 of Set 4 | parczew
# Processing Record 21 of Set 4 | tasiilaq
# Processing Record 22 of Set 4 | timizart
# Processing Record 23 of Set 4 | beatrice
# Processing Record 24 of Set 4 | wewak
# Processing Record 25 of Set 4 | surin
# Processing Record 26 of Set 4 | arroyo
# Processing Record 27 of Set 4 | magnor
# Processing Record 28 of Set 4 | filingue
# Processing Record 29 of Set 4 | nikolskoye
# Processing Record 30 of Set 4 | marzuq
# Processing Record 31 of Set 4 | tygda
# Processing Record 32 of Set 4 | carnarvon
# Processing Record 33 of Set 4 | olinda
# Processing Record 34 of Set 4 | ugoofaaru
# Processing Record 35 of Set 4 | seoul
# Processing Record 36 of Set 4 | kostino
# Processing Record 37 of Set 4 | nizwa
# Processing Record 38 of Set 4 | chokwe
# Processing Record 39 of Set 4 | norman wells
# Processing Record 40 of Set 4 | longonjo
# Processing Record 41 of Set 4 | nara
# Processing Record 42 of Set 4 | san quintin
# Processing Record 43 of Set 4 | esmeraldas
# Processing Record 44 of Set 4 | grand gaube
# Processing Record 45 of Set 4 | chuguyevka
# Processing Record 46 of Set 4 | buraydah
# Processing Record 47 of Set 4 | karlovac
# Processing Record 48 of Set 4 | zabaykalsk
# Processing Record 49 of Set 4 | clarksdale
# Processing Record 50 of Set 4 | pabna
# Processing Record 1 of Set 5 | comodoro rivadavia
# Processing Record 2 of Set 5 | korla
# Processing Record 3 of Set 5 | bilibino
# Processing Record 4 of Set 5 | fort frances
# Processing Record 5 of Set 5 | saint-philippe
# Processing Record 6 of Set 5 | port blair
# Processing Record 7 of Set 5 | arcos de la frontera
# Processing Record 8 of Set 5 | khonuu
# City not found. Skipping...
# Processing Record 9 of Set 5 | stoyba
# City not found. Skipping...
# Processing Record 10 of Set 5 | aiken
# Processing Record 11 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 12 of Set 5 | kloulklubed
# Processing Record 13 of Set 5 | kurilsk
# Processing Record 14 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 15 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 16 of Set 5 | ulaangom
# Processing Record 17 of Set 5 | georgetown
# Processing Record 18 of Set 5 | alyangula
# Processing Record 19 of Set 5 | husavik
# Processing Record 20 of Set 5 | arraial do cabo
# Processing Record 21 of Set 5 | bereda
# Processing Record 22 of Set 5 | vallenar
# Processing Record 23 of Set 5 | mandali
# Processing Record 24 of Set 5 | shiyan
# Processing Record 25 of Set 5 | sydney mines
# Processing Record 26 of Set 5 | chagda
# City not found. Skipping...
# Processing Record 27 of Set 5 | atuona
# Processing Record 28 of Set 5 | pevek
# Processing Record 29 of Set 5 | savannah bight
# Processing Record 30 of Set 5 | guerrero negro
# Processing Record 31 of Set 5 | chimoio
# Processing Record 32 of Set 5 | souillac
# Processing Record 33 of Set 5 | union
# Processing Record 34 of Set 5 | kruisfontein
# Processing Record 35 of Set 5 | puerto carreno
# Processing Record 36 of Set 5 | tecoanapa
# Processing Record 37 of Set 5 | cherskiy
# Processing Record 38 of Set 5 | zhanatas
# City not found. Skipping...
# Processing Record 39 of Set 5 | hambantota
# Processing Record 40 of Set 5 | tuktoyaktuk
# Processing Record 41 of Set 5 | dibrugarh
# Processing Record 42 of Set 5 | linkou
# Processing Record 43 of Set 5 | natal
# Processing Record 44 of Set 5 | escuintla
# Processing Record 45 of Set 5 | bubaque
# Processing Record 46 of Set 5 | mazatlan
# Processing Record 47 of Set 5 | yar-sale
# Processing Record 48 of Set 5 | airai
# Processing Record 49 of Set 5 | brusyliv
# Processing Record 50 of Set 5 | pathein
# Processing Record 1 of Set 6 | yinchuan
# Processing Record 2 of Set 6 | abonnema
# Processing Record 3 of Set 6 | sitka
# Processing Record 4 of Set 6 | conceicao do araguaia
# Processing Record 5 of Set 6 | olavarria
# Processing Record 6 of Set 6 | yulara
# Processing Record 7 of Set 6 | mahibadhoo
# Processing Record 8 of Set 6 | biala podlaska
# Processing Record 9 of Set 6 | qaqortoq
# Processing Record 10 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 11 of Set 6 | burlington
# Processing Record 12 of Set 6 | eydhafushi
# Processing Record 13 of Set 6 | alto longa
# Processing Record 14 of Set 6 | neiafu
# Processing Record 15 of Set 6 | san carlos
# Processing Record 16 of Set 6 | cap-chat
# Processing Record 17 of Set 6 | san policarpo
# Processing Record 18 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 19 of Set 6 | dikson
# Processing Record 20 of Set 6 | hamilton
# Processing Record 21 of Set 6 | umm jarr
# City not found. Skipping...
# Processing Record 22 of Set 6 | madimba
# Processing Record 23 of Set 6 | terra santa
# Processing Record 24 of Set 6 | chokurdakh
# Processing Record 25 of Set 6 | ahipara
# Processing Record 26 of Set 6 | camocim
# Processing Record 27 of Set 6 | hit
# Processing Record 28 of Set 6 | kedrovyy
# Processing Record 29 of Set 6 | hithadhoo
# Processing Record 30 of Set 6 | bathsheba
# Processing Record 31 of Set 6 | woodward
# Processing Record 32 of Set 6 | praya
# Processing Record 33 of Set 6 | pangnirtung
# Processing Record 34 of Set 6 | cabo san lucas
# Processing Record 35 of Set 6 | zruc nad sazavou
# Processing Record 36 of Set 6 | makakilo city
# Processing Record 37 of Set 6 | manavalakurichi
# Processing Record 38 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 39 of Set 6 | kalmunai
# Processing Record 40 of Set 6 | oksfjord
# Processing Record 41 of Set 6 | samarai
# Processing Record 42 of Set 6 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 43 of Set 6 | bismarck
# Processing Record 44 of Set 6 | muswellbrook
# Processing Record 45 of Set 6 | hilo
# Processing Record 46 of Set 6 | genhe
# Processing Record 47 of Set 6 | perth
# Processing Record 48 of Set 6 | vilhena
# Processing Record 49 of Set 6 | tuatapere
# Processing Record 50 of Set 6 | kismayo
# Processing Record 1 of Set 7 | karamay
# City not found. Skipping...
# Processing Record 2 of Set 7 | vestmannaeyjar
# Processing Record 3 of Set 7 | norrtalje
# Processing Record 4 of Set 7 | moron
# Processing Record 5 of Set 7 | dzilam gonzalez
# Processing Record 6 of Set 7 | pochutla
# Processing Record 7 of Set 7 | goderich
# Processing Record 8 of Set 7 | rabak
# Processing Record 9 of Set 7 | cayenne
# Processing Record 10 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 11 of Set 7 | sioux lookout
# Processing Record 12 of Set 7 | markova
# Processing Record 13 of Set 7 | hong gai
# Processing Record 14 of Set 7 | asahikawa
# Processing Record 15 of Set 7 | trento
# Processing Record 16 of Set 7 | kearney
# Processing Record 17 of Set 7 | esna
# Processing Record 18 of Set 7 | mount isa
# Processing Record 19 of Set 7 | provideniya
# Processing Record 20 of Set 7 | high level
# Processing Record 21 of Set 7 | college
# Processing Record 22 of Set 7 | sao miguel do araguaia
# Processing Record 23 of Set 7 | teguise
# Processing Record 24 of Set 7 | lembeni
# Processing Record 25 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 26 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 27 of Set 7 | afgoye
# City not found. Skipping...
# Processing Record 28 of Set 7 | nome
# Processing Record 29 of Set 7 | belmonte
# Processing Record 30 of Set 7 | mansfield
# Processing Record 31 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 32 of Set 7 | shakawe
# Processing Record 33 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 34 of Set 7 | kemijarvi
# Processing Record 35 of Set 7 | mazamet
# Processing Record 36 of Set 7 | gorontalo
# Processing Record 37 of Set 7 | almeirim
# Processing Record 38 of Set 7 | kijang
# Processing Record 39 of Set 7 | yumen
# Processing Record 40 of Set 7 | sokoni
# Processing Record 41 of Set 7 | okha
# Processing Record 42 of Set 7 | aklavik
# Processing Record 43 of Set 7 | cam ranh
# Processing Record 44 of Set 7 | lata
# Processing Record 45 of Set 7 | itum-kale
# Processing Record 46 of Set 7 | taoudenni
# Processing Record 47 of Set 7 | scottsburgh
# City not found. Skipping...
# Processing Record 48 of Set 7 | linhai
# Processing Record 49 of Set 7 | banepa
# Processing Record 50 of Set 7 | umm ruwabah
# City not found. Skipping...
# Processing Record 1 of Set 8 | severo-kurilsk
# Processing Record 2 of Set 8 | hofn
# Processing Record 3 of Set 8 | daru
# Processing Record 4 of Set 8 | itapipoca
# Processing Record 5 of Set 8 | shahrud
# Processing Record 6 of Set 8 | chuy
# Processing Record 7 of Set 8 | bitung
# Processing Record 8 of Set 8 | broome
# Processing Record 9 of Set 8 | saldanha
# Processing Record 10 of Set 8 | naryan-mar
# Processing Record 11 of Set 8 | porto seguro
# Processing Record 12 of Set 8 | jalu
# Processing Record 13 of Set 8 | bonavista
# Processing Record 14 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 15 of Set 8 | lethem
# Processing Record 16 of Set 8 | ixtapa
# Processing Record 17 of Set 8 | saint-joseph
# Processing Record 18 of Set 8 | raudeberg
# Processing Record 19 of Set 8 | fort saint john
# City not found. Skipping...
# Processing Record 20 of Set 8 | srednekolymsk
# Processing Record 21 of Set 8 | half moon bay
# Processing Record 22 of Set 8 | humaita
# Processing Record 23 of Set 8 | tanout
# Processing Record 24 of Set 8 | ramsar
# Processing Record 25 of Set 8 | muromtsevo
# Processing Record 26 of Set 8 | qarqin
# Processing Record 27 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 28 of Set 8 | hasaki
# Processing Record 29 of Set 8 | huazolotitlan
# City not found. Skipping...
# Processing Record 30 of Set 8 | sorsk
# Processing Record 31 of Set 8 | port hardy
# Processing Record 32 of Set 8 | porto novo
# Processing Record 33 of Set 8 | nyurba
# Processing Record 34 of Set 8 | banjarmasin
# Processing Record 35 of Set 8 | moscow
# Processing Record 36 of Set 8 | tecolutla
# Processing Record 37 of Set 8 | ouegoa
# Processing Record 38 of Set 8 | camopi
# Processing Record 39 of Set 8 | hokitika
# Processing Record 40 of Set 8 | pozhva
# Processing Record 41 of Set 8 | peleduy
# Processing Record 42 of Set 8 | usinsk
# Processing Record 43 of Set 8 | mana
# Processing Record 44 of Set 8 | flin flon
# Processing Record 45 of Set 8 | mayumba
# Processing Record 46 of Set 8 | dinsor
# City not found. Skipping...
# Processing Record 47 of Set 8 | touros
# Processing Record 48 of Set 8 | altay
# Processing Record 49 of Set 8 | sao joao da barra
# Processing Record 50 of Set 8 | byron bay
# Processing Record 1 of Set 9 | lagoa
# Processing Record 2 of Set 9 | arman
# Processing Record 3 of Set 9 | lavrentiya
# Processing Record 4 of Set 9 | jijiga
# Processing Record 5 of Set 9 | namibe
# Processing Record 6 of Set 9 | sondrio
# Processing Record 7 of Set 9 | salalah
# Processing Record 8 of Set 9 | mazagao
# Processing Record 9 of Set 9 | kiunga
# Processing Record 10 of Set 9 | paita
# Processing Record 11 of Set 9 | pangody
# Processing Record 12 of Set 9 | solwezi
# Processing Record 13 of Set 9 | skibbereen
# Processing Record 14 of Set 9 | skjeberg
# Processing Record 15 of Set 9 | klaksvik
# Processing Record 16 of Set 9 | port keats
# Processing Record 17 of Set 9 | chama
# Processing Record 18 of Set 9 | constitucion
# Processing Record 19 of Set 9 | teguldet
# Processing Record 20 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 21 of Set 9 | vangaindrano
# Processing Record 22 of Set 9 | ericeira
# Processing Record 23 of Set 9 | acapulco
# Processing Record 24 of Set 9 | baykit
# Processing Record 25 of Set 9 | snyder
# Processing Record 26 of Set 9 | oda
# Processing Record 27 of Set 9 | tongliao
# Processing Record 28 of Set 9 | roebourne
# Processing Record 29 of Set 9 | aksarka
# Processing Record 30 of Set 9 | ozimek
# Processing Record 31 of Set 9 | vanersborg
# Processing Record 32 of Set 9 | whitianga
# Processing Record 33 of Set 9 | nicoya
# Processing Record 34 of Set 9 | douglas
# Processing Record 35 of Set 9 | vila
# Processing Record 36 of Set 9 | ilhabela
# Processing Record 37 of Set 9 | kribi
# Processing Record 38 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 39 of Set 9 | mount gambier
# Processing Record 40 of Set 9 | punakha
# Processing Record 41 of Set 9 | huarmey
# Processing Record 42 of Set 9 | pecos
# Processing Record 43 of Set 9 | teacapan
# Processing Record 44 of Set 9 | coquimbo
# Processing Record 45 of Set 9 | avenal
# Processing Record 46 of Set 9 | nelson bay
# Processing Record 47 of Set 9 | lubao
# Processing Record 48 of Set 9 | izumo
# Processing Record 49 of Set 9 | dakoro
# Processing Record 50 of Set 9 | springbok
# Processing Record 1 of Set 10 | deputatskiy
# Processing Record 2 of Set 10 | mouila
# Processing Record 3 of Set 10 | hirara
# Processing Record 4 of Set 10 | zlobin
# Processing Record 5 of Set 10 | falealupo
# City not found. Skipping...
# Processing Record 6 of Set 10 | port hedland
# Processing Record 7 of Set 10 | clyde river
# Processing Record 8 of Set 10 | kavaratti
# Processing Record 9 of Set 10 | ken caryl
# Processing Record 10 of Set 10 | sakaiminato
# Processing Record 11 of Set 10 | codrington
# Processing Record 12 of Set 10 | ijaki
# City not found. Skipping...
# Processing Record 13 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 14 of Set 10 | fortuna
# Processing Record 15 of Set 10 | leningradskiy
# Processing Record 16 of Set 10 | ketchikan
# Processing Record 17 of Set 10 | le port
# Processing Record 18 of Set 10 | maine-soroa
# Processing Record 19 of Set 10 | bilma
# Processing Record 20 of Set 10 | sarai
# Processing Record 21 of Set 10 | iquitos
# Processing Record 22 of Set 10 | karkaralinsk
# City not found. Skipping...
# Processing Record 23 of Set 10 | tougue
# Processing Record 24 of Set 10 | camacha
# Processing Record 25 of Set 10 | ponta delgada
# Processing Record 26 of Set 10 | lompoc
# Processing Record 27 of Set 10 | zalesovo
# Processing Record 28 of Set 10 | narwana
# Processing Record 29 of Set 10 | angoche
# Processing Record 30 of Set 10 | amli
# Processing Record 31 of Set 10 | trat
# Processing Record 32 of Set 10 | port shepstone
# Processing Record 33 of Set 10 | kudahuvadhoo
# Processing Record 34 of Set 10 | neuquen
# Processing Record 35 of Set 10 | torbay
# Processing Record 36 of Set 10 | copiapo
# Processing Record 37 of Set 10 | haines junction
# Processing Record 38 of Set 10 | kibaya
# Processing Record 39 of Set 10 | dalvik
# Processing Record 40 of Set 10 | kokopo
# Processing Record 41 of Set 10 | dongsheng
# Processing Record 42 of Set 10 | kushiro
# Processing Record 43 of Set 10 | bac lieu
# Processing Record 44 of Set 10 | arrecife
# Processing Record 45 of Set 10 | ornskoldsvik
# Processing Record 46 of Set 10 | northam
# Processing Record 47 of Set 10 | san patricio
# Processing Record 48 of Set 10 | ikole
# City not found. Skipping...
# Processing Record 49 of Set 10 | yueyang
# Processing Record 50 of Set 10 | chitipa
# Processing Record 1 of Set 11 | bud
# Processing Record 2 of Set 11 | cartagena
# Processing Record 3 of Set 11 | biak
# Processing Record 4 of Set 11 | kahului
# Processing Record 5 of Set 11 | gidam
# Processing Record 6 of Set 11 | shangrao
# Processing Record 7 of Set 11 | longido
# Processing Record 8 of Set 11 | brigantine
# Processing Record 9 of Set 11 | fershampenuaz
# Processing Record 10 of Set 11 | jaru
# Processing Record 11 of Set 11 | timmins
# Processing Record 12 of Set 11 | okhotsk
# Processing Record 13 of Set 11 | betki
# City not found. Skipping...
# Processing Record 14 of Set 11 | ahuimanu
# Processing Record 15 of Set 11 | vila franca do campo
# Processing Record 16 of Set 11 | eureka
# Processing Record 17 of Set 11 | bandiagara
# Processing Record 18 of Set 11 | ahar
# Processing Record 19 of Set 11 | duku
# Processing Record 20 of Set 11 | garowe
# Processing Record 21 of Set 11 | yerbogachen
# Processing Record 22 of Set 11 | paso de los toros
# Processing Record 23 of Set 11 | moses lake
# Processing Record 24 of Set 11 | toktogul
# Processing Record 25 of Set 11 | ilebo
# Processing Record 26 of Set 11 | kwinana
# Processing Record 27 of Set 11 | beringovskiy
# Processing Record 28 of Set 11 | katobu
# Processing Record 29 of Set 11 | oktyabrskiy
# Processing Record 30 of Set 11 | iwanai
# Processing Record 31 of Set 11 | aberdeen
# Processing Record 32 of Set 11 | omalur
# Processing Record 33 of Set 11 | olafsvik
# Processing Record 34 of Set 11 | shiraz
# Processing Record 35 of Set 11 | morondava
# Processing Record 36 of Set 11 | hanstholm
# Processing Record 37 of Set 11 | kodino
# Processing Record 38 of Set 11 | guiratinga
# Processing Record 39 of Set 11 | dingle
# Processing Record 40 of Set 11 | port augusta
# Processing Record 41 of Set 11 | malgrat de mar
# Processing Record 42 of Set 11 | pandrup
# Processing Record 43 of Set 11 | tamale
# Processing Record 44 of Set 11 | sarakhs
# Processing Record 45 of Set 11 | forrest city
# Processing Record 46 of Set 11 | tam ky
# Processing Record 47 of Set 11 | fartura
# Processing Record 48 of Set 11 | sistranda
# Processing Record 49 of Set 11 | vila velha
# Processing Record 50 of Set 11 | formoso do araguaia
# City not found. Skipping...
# Processing Record 1 of Set 12 | dali
# Processing Record 2 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 3 of Set 12 | yenisehir
# Processing Record 4 of Set 12 | santiago del estero
# Processing Record 5 of Set 12 | kazachinskoye
# Processing Record 6 of Set 12 | cuiluan
# Processing Record 7 of Set 12 | suraabad
# Processing Record 8 of Set 12 | tutoia
# Processing Record 9 of Set 12 | rio gallegos
# Processing Record 10 of Set 12 | arlit
# Processing Record 11 of Set 12 | iqaluit
# Processing Record 12 of Set 12 | quebec
# Processing Record 13 of Set 12 | yoichi
# Processing Record 14 of Set 12 | kodinsk
# Processing Record 15 of Set 12 | saundatti yellamma
# City not found. Skipping...
# Processing Record 16 of Set 12 | mtwara
# Processing Record 17 of Set 12 | begoro
# Processing Record 18 of Set 12 | klichka
# Processing Record 19 of Set 12 | roald
# Processing Record 20 of Set 12 | saint anthony
# Processing Record 21 of Set 12 | mocuba
# Processing Record 22 of Set 12 | tilichiki
# Processing Record 23 of Set 12 | aleksinac
# Processing Record 24 of Set 12 | redcar
# Processing Record 25 of Set 12 | tidore
# City not found. Skipping...
# Processing Record 26 of Set 12 | fukue
# Processing Record 27 of Set 12 | mizdah
# Processing Record 28 of Set 12 | adrar
# Processing Record 29 of Set 12 | hirado
# Processing Record 30 of Set 12 | brenes
# Processing Record 31 of Set 12 | boone
# Processing Record 32 of Set 12 | san-pedro
# Processing Record 33 of Set 12 | almenevo
# City not found. Skipping...
# Processing Record 34 of Set 12 | sharan
# Processing Record 35 of Set 12 | kampong cham
# Processing Record 36 of Set 12 | laguna
# Processing Record 37 of Set 12 | oranjemund
# Processing Record 38 of Set 12 | namatanai
# Processing Record 39 of Set 12 | champerico
# Processing Record 40 of Set 12 | madina
# Processing Record 41 of Set 12 | baruun-urt
# Processing Record 42 of Set 12 | estevan
# Processing Record 43 of Set 12 | bajo baudo
# City not found. Skipping...
# Processing Record 44 of Set 12 | gimli
# Processing Record 45 of Set 12 | carballo
# Processing Record 46 of Set 12 | adamas
# Processing Record 47 of Set 12 | cap malheureux
# Processing Record 48 of Set 12 | gawler
# Processing Record 49 of Set 12 | saint george
# Processing Record 50 of Set 12 | simbahan
# Processing Record 1 of Set 13 | tiznit
# Processing Record 2 of Set 13 | inta
# Processing Record 3 of Set 13 | zharkent
# Processing Record 4 of Set 13 | gumushane
# City not found. Skipping...
# Processing Record 5 of Set 13 | inirida
# Processing Record 6 of Set 13 | kawalu
# Processing Record 7 of Set 13 | yaan
# Processing Record 8 of Set 13 | bahraich
# Processing Record 9 of Set 13 | jasper
# Processing Record 10 of Set 13 | dolbeau
# City not found. Skipping...
# Processing Record 11 of Set 13 | santa rosa
# Processing Record 12 of Set 13 | sabha
# Processing Record 13 of Set 13 | richards bay
# Processing Record 14 of Set 13 | pemangkat
# Processing Record 15 of Set 13 | shingu
# Processing Record 16 of Set 13 | henties bay
# Processing Record 17 of Set 13 | massaguet
# Processing Record 18 of Set 13 | vestmanna
# Processing Record 19 of Set 13 | charters towers
# Processing Record 20 of Set 13 | ginir
# Processing Record 21 of Set 13 | nanzhou
# Processing Record 22 of Set 13 | jinchang
# Processing Record 23 of Set 13 | udalguri
# Processing Record 24 of Set 13 | sinegorye
# Processing Record 25 of Set 13 | abnub
# Processing Record 26 of Set 13 | kargil
# Processing Record 27 of Set 13 | pacific grove
# Processing Record 28 of Set 13 | nabire
# Processing Record 29 of Set 13 | mayahi
# Processing Record 30 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 31 of Set 13 | the pas
# Processing Record 32 of Set 13 | lom sak
# Processing Record 33 of Set 13 | gualeguaychu
# Processing Record 34 of Set 13 | general pico
# Processing Record 35 of Set 13 | amboasary
# Processing Record 36 of Set 13 | fort nelson
# Processing Record 37 of Set 13 | unity
# Processing Record 38 of Set 13 | sainte-marie
# Processing Record 39 of Set 13 | severnyy
# Processing Record 40 of Set 13 | flinders
# Processing Record 41 of Set 13 | cairns
# Processing Record 42 of Set 13 | campo de criptana
# Processing Record 43 of Set 13 | ballina
# Processing Record 44 of Set 13 | casper
# Processing Record 45 of Set 13 | ewa beach
# Processing Record 46 of Set 13 | manokwari
# Processing Record 47 of Set 13 | pandamatenga
# Processing Record 48 of Set 13 | bend
# Processing Record 49 of Set 13 | wawa
# Processing Record 50 of Set 13 | kendari
# Processing Record 1 of Set 14 | krasnoyarsk
# Processing Record 2 of Set 14 | lasa
# Processing Record 3 of Set 14 | paamiut
# Processing Record 4 of Set 14 | kualakapuas
# Processing Record 5 of Set 14 | tautira
# Processing Record 6 of Set 14 | collie
# Processing Record 7 of Set 14 | fornosovo
# Processing Record 8 of Set 14 | kovernino
# Processing Record 9 of Set 14 | jumla
# Processing Record 10 of Set 14 | ambilobe
# Processing Record 11 of Set 14 | asbestos
# Processing Record 12 of Set 14 | iralaya
# Processing Record 13 of Set 14 | tocopilla
# Processing Record 14 of Set 14 | kokstad
# Processing Record 15 of Set 14 | sambava
# Processing Record 16 of Set 14 | kilrush
# Processing Record 17 of Set 14 | pekan
# Processing Record 18 of Set 14 | mehamn
# Processing Record 19 of Set 14 | kathu
# Processing Record 20 of Set 14 | shahr-e babak
# Processing Record 21 of Set 14 | lianzhou
# Processing Record 22 of Set 14 | calama
# Processing Record 23 of Set 14 | rio grande
# Processing Record 24 of Set 14 | artyk
# City not found. Skipping...
# Processing Record 25 of Set 14 | sinnai
# Processing Record 26 of Set 14 | sawtell
# Processing Record 27 of Set 14 | aptos
# Processing Record 28 of Set 14 | rocha
# Processing Record 29 of Set 14 | varhaug
# Processing Record 30 of Set 14 | kos
# Processing Record 31 of Set 14 | elliot lake
# Processing Record 32 of Set 14 | saint augustine
# Processing Record 33 of Set 14 | west wendover
# Processing Record 34 of Set 14 | darhan
# Processing Record 35 of Set 14 | stege
# Processing Record 36 of Set 14 | saint-georges
# Processing Record 37 of Set 14 | popondetta
# Processing Record 38 of Set 14 | palana
# Processing Record 39 of Set 14 | halifax
# Processing Record 40 of Set 14 | coshocton
# Processing Record 41 of Set 14 | obra
# Processing Record 42 of Set 14 | machali
# Processing Record 43 of Set 14 | price
# Processing Record 44 of Set 14 | tevriz
# Processing Record 45 of Set 14 | lisala
# Processing Record 46 of Set 14 | breisach
# Processing Record 47 of Set 14 | praia da vitoria
# Processing Record 48 of Set 14 | awjilah
# Processing Record 49 of Set 14 | nishihara
# Processing Record 50 of Set 14 | linxia
# Processing Record 1 of Set 15 | mercedes
# Processing Record 2 of Set 15 | thinadhoo
# Processing Record 3 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 4 of Set 15 | krasnoselkup
# Processing Record 5 of Set 15 | chicama
# Processing Record 6 of Set 15 | podgornoye
# Processing Record 7 of Set 15 | arenys de mar
# Processing Record 8 of Set 15 | humboldt
# Processing Record 9 of Set 15 | muzhi
# Processing Record 10 of Set 15 | minna
# Processing Record 11 of Set 15 | rolim de moura
# City not found. Skipping...
# Processing Record 12 of Set 15 | santo tomas
# Processing Record 13 of Set 15 | anadyr
# Processing Record 14 of Set 15 | laizhou
# Processing Record 15 of Set 15 | mayo
# Processing Record 16 of Set 15 | komsomolskiy
# Processing Record 17 of Set 15 | chebenki
# Processing Record 18 of Set 15 | dudinka
# Processing Record 19 of Set 15 | staryy nadym
# Processing Record 20 of Set 15 | gat
# Processing Record 21 of Set 15 | andevoranto
# City not found. Skipping...
# Processing Record 22 of Set 15 | kasongo
# Processing Record 23 of Set 15 | ayorou
# Processing Record 24 of Set 15 | kundiawa
# Processing Record 25 of Set 15 | hagi
# Processing Record 26 of Set 15 | nemuro
# Processing Record 27 of Set 15 | matir
# City not found. Skipping...
# Processing Record 28 of Set 15 | bowen
# Processing Record 29 of Set 15 | ikwiriri
# Processing Record 30 of Set 15 | san rafael
# Processing Record 31 of Set 15 | parabel
# Processing Record 32 of Set 15 | telde
# Processing Record 33 of Set 15 | harper
# Processing Record 34 of Set 15 | malakal
# Processing Record 35 of Set 15 | paraiso
# Processing Record 36 of Set 15 | dukat
# Processing Record 37 of Set 15 | beyneu
# Processing Record 38 of Set 15 | kolyvan
# Processing Record 39 of Set 15 | passy
# Processing Record 40 of Set 15 | axim
# Processing Record 41 of Set 15 | opobo
# City not found. Skipping...
# Processing Record 42 of Set 15 | quatre cocos
# Processing Record 43 of Set 15 | wellington
# Processing Record 44 of Set 15 | zhetybay
# City not found. Skipping...
# Processing Record 45 of Set 15 | terney
# Processing Record 46 of Set 15 | presidencia roque saenz pena
# Processing Record 47 of Set 15 | lichinga
# Processing Record 48 of Set 15 | gorom-gorom
# Processing Record 49 of Set 15 | billings
# Processing Record 50 of Set 15 | aleksandrow kujawski
# Processing Record 1 of Set 16 | talawdi
# City not found. Skipping...
# Processing Record 2 of Set 16 | tiarei
# Processing Record 3 of Set 16 | nisia floresta
# Processing Record 4 of Set 16 | talnakh
# Processing Record 5 of Set 16 | sinait
# Processing Record 6 of Set 16 | casino
# Processing Record 7 of Set 16 | kachikau
# City not found. Skipping...
# Processing Record 8 of Set 16 | sur
# Processing Record 9 of Set 16 | bartoszyce
# Processing Record 10 of Set 16 | trairi
# Processing Record 11 of Set 16 | tomatlan
# Processing Record 12 of Set 16 | zelenogradskiy
# Processing Record 13 of Set 16 | stryn
# Processing Record 14 of Set 16 | nadym
# Processing Record 15 of Set 16 | ziyang
# Processing Record 16 of Set 16 | catole do rocha
# Processing Record 17 of Set 16 | caravelas
# Processing Record 18 of Set 16 | iberia
# Processing Record 19 of Set 16 | nedjo
# Processing Record 20 of Set 16 | coihaique
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Check to see how many cities were found.
len(city_data)
# Out:
# 704

# %%
# Create a new dataframe with the weather description.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0               Raga   8.4596   25.6780     68.36        25          63
# 1           Kirakira -10.4544  161.9205     85.33        73          81
# 2            Mataura -46.1927  168.8643     56.48        45          74
# 3  Nizhniy Tsasuchey  50.5167  115.1333     -8.66        99          92
# 4             Yongan  39.6957  113.6871     21.72        89           7
# 5         Sao Filipe  14.8961  -24.4956     74.64        74          89
# 6       Punta Arenas -53.1500  -70.9167     53.71        66          75
# 7        East London -33.0153   27.9116     72.66        71           0
# 8           Orotukan  62.2667  151.7000    -31.20        89          80
# 9              Kapaa  22.0752 -159.3190     76.98        77         100
#
#    Wind Speed Country Current Description
# 0        3.24      SS       broken clouds
# 1        9.53      SB       broken clouds
# 2        7.02      NZ       broken clouds
# 3        1.54      RU     overcast clouds
# 4        1.54      CN           clear sky
# 5        4.70      CV     overcast clouds
# 6       11.50      CL       broken clouds
# 7       18.07      ZA           clear sky
# 8        3.69      RU       broken clouds
# 9        1.01      US     overcast clouds

# %%
# Create the new column order
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# %%
# Create the new dataframe with the updated column order.
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#                   City Country      Lat       Lng  Max Temp  Humidity  \
# 0                 Raga      SS   8.4596   25.6780     68.36        25
# 1             Kirakira      SB -10.4544  161.9205     85.33        73
# 2              Mataura      NZ -46.1927  168.8643     56.48        45
# 3    Nizhniy Tsasuchey      RU  50.5167  115.1333     -8.66        99
# 4               Yongan      CN  39.6957  113.6871     21.72        89
# ..                 ...     ...      ...       ...       ...       ...
# 699    Catole Do Rocha      BR  -6.3439  -37.7467     81.07        56
# 700          Caravelas      BR -17.7125  -39.2481     76.93        81
# 701             Iberia      US  29.9502  -91.7507     44.96        34
# 702              Nedjo      ET   9.5046   35.5019     59.68        49
# 703          Coihaique      CL -45.5752  -72.0662     57.15        47
#
#      Cloudiness  Wind Speed Current Description
# 0            63        3.24       broken clouds
# 1            81        9.53       broken clouds
# 2            74        7.02       broken clouds
# 3            92        1.54     overcast clouds
# 4             7        1.54           clear sky
# ..          ...         ...                 ...
# 699          28        9.08    scattered clouds
# 700          10        6.26           clear sky
# 701           0       10.94           clear sky
# 702         100        4.12     overcast clouds
# 703          75        9.22       broken clouds
#
# [704 rows x 9 columns]

# %%
# Create the CSV file.
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
